# %%
# Fixed: Use None as default and create new list
def add_item(item, items=None):
    if items is None:
        items = []
    items.append(item)
    return items

print(add_item(1))
print(add_item(2))
# Out:
# [1]
# [2]

# %%
def check_sum():
    return abs((0.1 + 0.2) - 0.3) < 1e-9

print(check_sum())
# Out:
# True

# %%
def countdown(n):
    if n < 0:
        return
    print(n)
    return countdown(n-1)

countdown(5)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %%
def get_value():
    data = {"a": 1, "b": 2}
    return data.get("c", None)  # Returns None if key doesn't exist

print(get_value())
# Out:
# None

# %%
def loop_example():
    i = 0
    while i < 5:
        print(i)
        i += 1

loop_example()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
a, b, c = (1, 2, 3)
print(a, b, c)
# Out:
# 1 2 3

# %%
def func():
    x = 5
    y = 10
    return x + y

print(func())
# Out:
# 15

# %%
import math

print(math.sqrt(16))
# Out:
# 4.0

# %%
def total(numbers):
    result = 0
    for n in numbers:
        result += n
    return result

print(total([1,2,3]))
# Out:
# 6

# %%
def calculate_area(length, width):
    return length * width

print(calculate_area(a, b))
# Out:
# 2

# %%
def add_values():
    return 5 + int("10")

print(add_values())
# Out:
# 15

# %%
def combine():
    return "Numbers: " + ", ".join(map(str, [1, 2, 3]))

print(combine())
# Out:
# Numbers: 1, 2, 3

# %%
def repeat_text():
    return "Hello" * int(2.5)

print(repeat_text())
# Out:
# HelloHello

# %%
def compute():
    value = None
    if value is None:
        value = 0
    return value + 10

print(compute())
# Out:
# 10

# %%
def sum_two_numbers():
    x = input("Enter first number: ")
    y = input("Enter second number: ")
    try:
        return float(x) + float(y)
    except ValueError:
        print("Please enter valid numbers")
        return None

print(sum_two_numbers())
# Out:
# 9.0
